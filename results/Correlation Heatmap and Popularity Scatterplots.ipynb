# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/zolbur13/Downloads/Integrated.csv")
df
# Out:
#      Unnamed: 0                track_id                    artists  \
# 0             0  6dwkFmLUz6hx2CZG2EqLol                  Howie Day
# 1             1  3bat14NdN3flvcsEMpVOFq              Black Messiah
# 2             2  6ZiaGtb94L6LtRbC3yHkJW            Old Man's Child
# 3             3  3e0tyTV5FiV1bcYeRjdDz2                  Moonspell
# 4             4  0zTdT65lUqepmx7N5dwVRj                  Moonspell
# ..          ...                     ...                        ...
# 128         128  4J0phvYcKa1Hr1EBwH0pu3  Los Auténticos Decadentes
# 129         129  3KwxfGupNXVbQnRz0FkOPp    Los Fabulosos Cadillacs
# 130         130  4wN3FpTUeX142D60F23AEZ               Simple Minds
# 131         131  3CjQAbOyux9kiLgO98N6Ff               Simple Minds
# 132         132  6bF7vDIjykeAeC706WE2KW             Mustafa Sandal
#
#                           album_name  \
# 0             Stop All The World Now
# 1             First War of the World
# 2           In Defiance of Existence
# 3                       Sin / Pecado
# 4             Lisboa Under the Spell
# ..                               ...
# 128                      Supersonico
# 129           Originales - 20 Exitos
# 130  Once Upon A Time (Super Deluxe)
# 131                 Once Upon A Time
# 132                     Gölgede Aynı
#
#                                      track_name  popularity  duration_ms  \
# 0                                       Collide          66       249120
# 1                                      Gullveig          20       488533
# 2                                 Life Deprived          18       289346
# 3                                The Hanged Man          18       386333
# 4                                    Alma Mater          17       411506
# ..                                          ...         ...          ...
# 128                     Qué Vas a Hacer Conmigo          37       206933
# 129  Manuel Santillán, el León - Versión Reggae          37       236066
# 130                    Sanctify Yourself - Edit          26       234133
# 131         Sanctify Yourself - Remastered 2002          25       297453
# 132                               İki Tas Çorba          40       228200
#
#      explicit  danceability  energy  ...  instrumentalness  liveness  valence  \
# 0       False         0.636   0.625  ...          0.000053    0.1190   0.3420
# 1       False         0.558   0.969  ...          0.073500    0.3340   0.5410
# 2       False         0.183   0.887  ...          0.893000    0.3560   0.1500
# 3       False         0.404   0.636  ...          0.653000    0.0795   0.0979
# 4       False         0.337   0.955  ...          0.891000    0.8620   0.1510
# ..        ...           ...     ...  ...               ...       ...      ...
# 128     False         0.615   0.586  ...          0.000001    0.1450   0.7630
# 129     False         0.771   0.902  ...          0.000062    0.3320   0.9550
# 130     False         0.531   0.948  ...          0.000025    0.7510   0.5950
# 131     False         0.564   0.912  ...          0.000669    0.6720   0.7240
# 132     False         0.619   0.433  ...          0.002150    0.1520   0.7820
#
#        tempo  track_genre  ArtistFamiliarity   Hotness  end_of_fade_in  \
# 0     93.931     acoustic           0.830642  0.546054           0.078
# 1    124.019  black-metal           0.506776  0.427798           0.000
# 2    157.824  black-metal           0.635483  0.428442           0.217
# 3    140.105  black-metal           0.722571  0.499826           0.177
# 4    142.457  black-metal           0.722571  0.499826           0.000
# ..       ...          ...                ...       ...             ...
# 128  130.221          ska           0.610331  0.407822           0.000
# 129  107.617          ska           0.774037  0.521727           0.178
# 130  128.096    synth-pop           0.700680  0.503362           1.040
# 131  128.219    synth-pop           0.700680  0.503362           1.040
# 132  170.178      turkish           0.589136  0.409248           0.420
#
#      Loudness start_of_fade_out
# 0     -12.316           268.011
# 1      -5.461           480.885
# 2      -5.520           285.896
# 3      -8.087           386.194
# 4      -5.255           307.345
# ..        ...               ...
# 128    -5.634           205.374
# 129    -4.879           234.144
# 130   -11.231           413.222
# 131   -11.231           413.222
# 132   -13.342           214.471
#
# [133 rows x 25 columns]

# %%
df[['energy','key', 'loudness', 'mode', 'speechiness', 'acousticness']]
# Out:
#      energy  key  loudness  mode  speechiness  acousticness
# 0     0.625   11    -7.895     1       0.0277      0.222000
# 1     0.969    9    -5.069     1       0.0649      0.001240
# 2     0.887    1    -5.990     1       0.0580      0.000003
# 3     0.636    4    -8.798     0       0.0325      0.064300
# 4     0.955    9    -5.061     0       0.0839      0.000006
# ..      ...  ...       ...   ...          ...           ...
# 128   0.586    0    -9.846     1       0.0339      0.163000
# 129   0.902    7    -1.598     0       0.0290      0.236000
# 130   0.948    0    -5.265     1       0.0533      0.277000
# 131   0.912    0    -6.055     1       0.0411      0.066100
# 132   0.433    8   -17.763     0       0.0424      0.729000
#
# [133 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'track_genre',
#        'ArtistFamiliarity', 'Hotness', 'end_of_fade_in', 'Loudness',
#        'start_of_fade_out'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

audio_features = [
    "popularity", "danceability", "energy", "key", "mode", "loudness",
    "speechiness", "acousticness", "instrumentalness",
    "liveness", "valence", "tempo",
    "ArtistFamiliarity", "Hotness"
]
cols = [c for c in audio_features if c in df.columns]

plt.figure(figsize=(14, 10))
sns.heatmap(df[cols].corr(), annot=False, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap of Audio Features (Full Feature Set)")
plt.show()

# %%
plt.figure(figsize=(14, 10))

# Popularity vs Energy
plt.subplot(2, 3, 1)
sns.scatterplot(data=df, x="energy", y="popularity", alpha=0.5)
plt.title("Popularity vs Energy")

# Popularity vs Loudness
plt.subplot(2, 3, 2)
sns.scatterplot(data=df, x="loudness", y="popularity", alpha=0.5)
plt.title("Popularity vs Loudness")

# Popularity vs Speechiness
plt.subplot(2, 3, 3)
sns.scatterplot(data=df, x="speechiness", y="popularity", alpha=0.5)
plt.title("Popularity vs Speechiness")

# Popularity vs Acousticness
plt.subplot(2, 3, 4)
sns.scatterplot(data=df, x="acousticness", y="popularity", alpha=0.5)
plt.title("Popularity vs Acousticness")

# Popularity vs Valence
plt.subplot(2, 3, 5)
sns.scatterplot(data=df, x="valence", y="popularity", alpha=0.5)
plt.title("Popularity vs Valence")

# Popularity vs Tempo
plt.subplot(2, 3, 6)
sns.scatterplot(data=df, x="tempo", y="popularity", alpha=0.5)
plt.title("Popularity vs Tempo")

plt.tight_layout()
plt.show()
